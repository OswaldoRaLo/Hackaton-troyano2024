# %% [markdown]
# ## Ejemplo

# %%
from fastapi import FastAPI
import numpy as np
import random
#import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from numpy import polyfit
from sklearn.model_selection import PolynomialFeatures

app = FastAPI()
X = np.linspace(0,2*np.pi,30)
Y = np.sin(X)+X
ruido = np.random.randn(30)
trayec = Y+0.6*ruido
fig, ax = plt.subplots()
ax.scatter(X,trayec)

# Grado del polinomio
poli_reg = PolynomialFeatures(degree = 2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       7 from sklearn.model_selection import train_test_split
#       8 from numpy import polyfit
# ----> 9 from sklearn.model_selection import PolynomialFeatures
#      12 X = np.linspace(0,2*np.pi,30)
#      13 Y = np.sin(X)+X
#
# ImportError: cannot import name 'PolynomialFeatures' from 'sklearn.model_selection' (c:\Users\maria\miniconda3\envs\TS2024\lib\site-packages\sklearn\model_selection\__init__.py)

# %% [markdown]
# ## Bondad del ajuste

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.6 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.6 kB 495.5 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.6 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 322.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 1.3 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/10.6 MB 1.2 MB/s eta 0:00:09
#     --------------------------------------- 0.2/10.6 MB 893.0 kB/s eta 0:00:12
#     --------------------------------------- 0.2/10.6 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/10.6 MB 1.2 MB/s eta 0:00:09
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# Datos
X = np.linspace(0, 2*np.pi, 30)
Y = np.sin(X) + X
ruido = 0.6 * np.random.randn(30)
trayectoria = Y + ruido

# Grado polinomio
grado_polinomio = 5

# Ajustar el grado del polinomio a la variable x
pipeline = Pipeline([
    ('poly_features', PolynomialFeatures(degree=grado_polinomio)),
    ('linear_reg', LinearRegression())
])

pipeline.fit(X[:, np.newaxis], trayectoria)

# 
X_test = np.linspace(0, 2*np.pi, 100)
y_pred = pipeline.predict(X_test[:, np.newaxis])

# Graficar los resultados
plt.scatter(X, trayectoria, label='Datos')
plt.plot(X_test, y_pred, color='red', label='Regresión polinomial no lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión polinomial no lineal de grado {}'.format(grado_polinomio))
plt.legend()
plt.show()
